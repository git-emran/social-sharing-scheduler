# %%
import setup
setup.init()

# %%
print("Hello World")
# Out:
# Hello World

# %%
from django.contrib.auth import get_user_model

# %%
User = get_user_model()

# %%
qs = User.objects.all()
qs
# Out:
# <QuerySet [<User: emran>, <User: emrantest>]>
