# %%
import setup
setup.init()

# %%
from django.contrib.auth import get_user_model

# %%
User = get_user_model()

# %%
user = User.objects.get(username="emran1")
user
# Out:
# <User: emran1>

# %%
user.socialaccount_set.all()
# Out:
# <QuerySet [<SocialAccount: emran1>]>

# %%
user_linkedin = user.socialaccount_set.first()
user_linkedin
# Out:
# <SocialAccount: emran1>

# %%
user_linkedin.provider
# Out:
# 'linkedin'

# %%
user_id = user_linkedin.uid

# %%
tokens = user_linkedin.socialtoken_set.all()
tokens
# Out:
# <QuerySet [<SocialToken: social application token (2)>]>

# %%
social_token = tokens.first()
social_token
# Out:
# <SocialToken: social application token (2)>

# %%
import requests

# %%
endpoint = "https://api.linkedin.com/v2/ugcPosts"
method = "POST"
headers = {
    "Authorization": f"Bearer {social_token.token}",
    "X-Restli-Protocol-Version": "2.0.0"
}

# %%
payload = {
    "author": f"urn:li:person:{user_id}",
    "lifecycleState": "PUBLISHED",
    "specificContent": {
        "com.linkedin.ugc.ShareContent": {
            "shareCommentary": {
                "text": "Hello Automating Linkedin post share !!"
            },
            "shareMediaCategory": "NONE"
        }
    },
    "visibility": {
        "com.linkedin.ugc.MemberNetworkVisibility": "PUBLIC"
    }
}

# %%
response = requests.post(endpoint, json=payload, headers=headers)
response.raise_for_status()
response.json()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 response = requests.post(endpoint, json=payload, headers=headers)
# ----> 2 response.raise_for_status()
#       3 response.json()
#
# File ~/Programming/social-share/venv/lib/python3.13/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.linkedin.com/v2/ugcPosts
