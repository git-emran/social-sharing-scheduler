# %%
import setup
setup.init()

# %%
from django.contrib.auth import get_user_model

# %%
User = get_user_model()

# %%
emran_user = User.objects.get(username='emran1')
text = "This is a post made from linkedin API. testing my webapp."

# %%
import helpers

# %%
from helpers import linkedin

# %%
linkedin.post_to_linkedin(emran_user, text)
# Out:
# <Response [201]>
